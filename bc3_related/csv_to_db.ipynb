# %%
import pandas as pd
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine

csv_file = "Data/deliver_to_effect.csv";
engine = create_engine("postgresql+psycopg2://shooca:shooca222@postgres:5432/shooca_db");

# %%
df = pd.read_csv(csv_file);

# %%
df.head(10)
# Out:
#   Callsign Platform Type  Formation Mode 3        Nat  \
# 0   MERLIN          F16C        4.0   3574        USA
# 1   PRAIRE          F16C        4.0   3616        USA
# 2    SAKER          F16J        4.0   3643      JAPAN
# 3     MAKO          F16C        4.0   3672        USA
# 4    SUNNY          F15E        4.0   3716        USA
# 5    GISMO          F15E        4.0   4041        USA
# 6    HARPY           F22        4.0   4320        USA
# 7     THOR          F35A        4.0   4246        USA
# 8     ZEUS          F35A        4.0   4265  AUSTRALIA
# 9  REDBULL          KC46        2.0   4123        USA
#
#                                    Comm Deliverables    Sensing Deliverables  \
# 0  UHF, Airborne Datalink, Leo Datalink, Comm SatCom                    AMTI
# 1  UHF, Airborne Datalink, Leo Datalink, Comm SatCom          AMTI, COMINT 1
# 2                UHF, Airborne Datalink, Comm SatCom           AMTI, IMINT 1
# ...

# %%
dfinsert = df.rename(columns={
    'Callsign': 'callsign', 
    'Platform Type': 'aircraft_type',
    'Formation': 'num_aircraft', 
    'Mode 3': 'mode3', 
    'Nat': 'nation', 
    'Comm Deliverables': 'comm_deliverables', 
    'Sensing Deliverables': 'sensing_deliverables', 
    'Kinetic Deliverables (Per A/C)': 'default_munitions', 
    'EA Deliverables': 'ea_deliverables',
    'Other Deliverables': 'other_deliverables'
})

dfinsert = dfinsert[['callsign', 'aircraft_type', 'num_aircraft', 'mode3', 'nation', 'comm_deliverables', 'sensing_deliverables', 'default_munitions', 'ea_deliverables', 'other_deliverables']]

# %%
dfinsert.head(20)
# Out:
#     callsign aircraft_type  num_aircraft mode3     nation  \
# 0     MERLIN          F16C           4.0  3574        USA
# 1     PRAIRE          F16C           4.0  3616        USA
# 2      SAKER          F16J           4.0  3643      JAPAN
# 3       MAKO          F16C           4.0  3672        USA
# 4      SUNNY          F15E           4.0  3716        USA
# 5      GISMO          F15E           4.0  4041        USA
# 6      HARPY           F22           4.0  4320        USA
# 7       THOR          F35A           4.0  4246        USA
# 8       ZEUS          F35A           4.0  4265  AUSTRALIA
# 9    REDBULL          KC46           2.0  4123        USA
# 10   MONSTER          KC46           2.0  4342        USA
# 11  ROCKSTAR         KC135           2.0  3252        USA
# 12     RIPIT         KC135           2.0  4361        USA
# 13      BANG         KC135           2.0  3323        USA
# 14    MARLEY         EA37B           2.0  2635        USA
# ...

# %%
dfinsert.to_sql('tmdash_ato', engine, schema='bc3lookup', index=False, if_exists="replace");
